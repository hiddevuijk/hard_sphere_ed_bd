# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ti = 2

Lx = 5
Ly = 5

positions = np.loadtxt("data/positions_" + str(ti) + ".dat")
print(positions)
fig, ax = plt.subplots()

for p in positions:
    x = p[0]
    y = p[1]
    x -= np.floor(x / Lx) * Lx
    y -= np.floor(y / Ly) * Ly
    print(x, y)
    circle = plt.Circle((x, y), 1.0) 
    circle.set_alpha(0.3)
    ax.add_artist(circle)
    
ax.set_xlim([0,Lx])
ax.set_ylim([0,Ly])
ax.set_aspect(1)
# Out:
# [[-0.00760977 -2.13021501  0.        ]
#  [-2.12088687  2.11558955  0.        ]]
# 4.992390234323453 2.869784994194755
# 2.879113129636145 2.115589552874143
