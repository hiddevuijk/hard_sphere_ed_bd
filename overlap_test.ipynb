# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ti = 3

Lx = 5
Ly = 5

positions = np.loadtxt("data/positions_" + str(ti) + ".dat")
print(positions)
fig, ax = plt.subplots()

for p in positions:
    x = p[0]
    y = p[1]
    x -= np.floor(x / Lx) * Lx
    y -= np.floor(y / Ly) * Ly
    print(x, y)
    circle = plt.Circle((x, y), 1.0) 
    circle.set_alpha(0.3)
    ax.add_artist(circle)
    
ax.set_xlim([0,Lx])
ax.set_ylim([0,Ly])
ax.set_aspect(1)
# Out:
# [[ 0.2861596  -0.38357016  0.        ]
#  [-0.21432376  1.7143297   0.        ]
#  [-0.22929767  4.13797752  0.        ]]
# 0.2861595999960027 4.616429842513815
# 4.785676239521923 1.714329696879028
# 4.770702328502301 4.137977521294098
